# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read CSV files.
beer_file= ("Resources/beers.csv")
brewery= ("Resources/breweries.csv")
beer_file= pd.read_csv(beer_file)
brewery_file= pd.read_csv(brewery)

# %%
# Show the data from the file
beer_file.head()
# Out:
#    Unnamed: 0    abv  ibu    id                 name  \
# 0           0  0.050  NaN  1436             Pub Beer
# 1           1  0.066  NaN  2265          Devil's Cup
# 2           2  0.071  NaN  2264  Rise of the Phoenix
# 3           3  0.090  NaN  2263             Sinister
# 4           4  0.075  NaN  2262        Sex and Candy
#
#                             style  brewery_id  ounces
# 0             American Pale Lager         408    12.0
# 1         American Pale Ale (APA)         177    12.0
# 2                    American IPA         177    12.0
# 3  American Double / Imperial IPA         177    12.0
# 4                    American IPA         177    12.0

# %%
# Show the data from the file
brewery_file.head()
# Out:
#    brewery_id                       name           city state
# 0           0         NorthGate Brewing     Minneapolis    MN
# 1           1  Against the Grain Brewery     Louisville    KY
# 2           2   Jack's Abby Craft Lagers     Framingham    MA
# 3           3  Mike Hess Brewing Company      San Diego    CA
# 4           4    Fort Point Beer Company  San Francisco    CA

# %% [markdown]
# # Best Location for a Brewery?

# %%
#Top States w/ Breweries
top_states = brewery_file['state'].value_counts().head(10)

x_axis = top_states.index.values
y_axis = top_states.values
plt.bar(x_axis,y_axis,color='#F9A602', align='center')
plt.yticks([0,10,20,30,40,50])
plt.ylabel('# of Breweries')
plt.xlabel('State')
plt.title('Top 10 States that Drink Beer')
plt.savefig('Images/Beer Lovers.png')
plt.show()

# %% [markdown]
# ### Figure 1 - *Notes*
# - Want to avoid top 3 states so there isn't too much competition
# - Aim for states like OR, TX, or PA where there still seems to be a demand for breweries but has less competition

# %%
#Bottom States w/ Breweries
bottom_states = brewery_file['state'].value_counts().tail(10)

x_axis = bottom_states.index.values
y_axis = bottom_states.values
plt.bar(x_axis,y_axis, align='center', color='#8B4513')
plt.yticks([0,10,20,30,40,50])
plt.ylabel('# of Breweries')
plt.xlabel('State')
plt.title('Bottom 10 States that Drink Beer')
plt.savefig('Images/Beer Haters.png')
plt.show()

# %% [markdown]
# ### Figure 2 - *Notes*
# - Won't want to start brewery in any bottom states bc consumer base is way too small.

# %%
brewery_file['city/state'] = brewery_file['city'] + ',' + brewery_file['state']
top_cities = brewery_file['city/state'].value_counts().head(10)

x_axis = top_cities.index.values
y_axis = top_cities.values
plt.bar(x_axis,y_axis, align='center', color='lightskyblue')
plt.yticks([0,3,6,9,12])
plt.xticks(rotation=90)
plt.ylabel('# of Breweries')
plt.xlabel('City')
plt.title('Cities with Highest Consumer Base')
plt.savefig('Images/Highest Consumer Base.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Figure 3 - *Notes*
# - Looking at top 10 cities in the US with the most breweries to see which city drinks the most beer.
